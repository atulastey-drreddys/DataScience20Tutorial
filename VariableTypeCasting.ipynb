# %% [markdown]
# # Variable

# %%
x = 546
print(x)
print(type(x))
# Out:
# 546
# <class 'int'>

# %%
X = 89
print(X)
print(type(X))
# Out:
# 89
# <class 'int'>

# %%
print(x,X)
# Out:
# 546 89

# %%
print(id(x))
print(id(X))
# Out:
# 3162406829424
# 140712712568360

# %%
a = 89
print(a)
print(id(a))
# Out:
# 89
# 140712712568360

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
6b = "Datascience"
print(6b)
# Out:
#   Cell In[9], line 1
#     6b = "Datascience"
#     ^
# SyntaxError: invalid decimal literal

# %%
b6 = "Datascience"
print(b6)
# Out:
# Datascience

# %%
_ = "Machine learning"
print(_)
# Out:
# Machine learning

# %%
* = "Hadoop"
print(*)
# Out:
#   Cell In[12], line 1
#     * = "Hadoop"
#       ^
# SyntaxError: invalid syntax

# %%
My name = "Atul singh"
print(My name)
# Out:
#   Cell In[13], line 1
#     My name = "Atul singh"
#        ^
# SyntaxError: invalid syntax

# %%
Myname = "Atul singh"
print(Myname)
# Out:
# Atul singh

# %%
My_name = "Atul singh"
print(My_name)
# Out:
# Atul singh

# %%
for = "Zookeeper"
print(for)
# Out:
#   Cell In[16], line 1
#     for = "Zookeeper"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Zookeeper"
print(For)
# Out:
# Zookeeper

# %% [markdown]
# # Type Casting

# %%
# implicit

a = 56
b = 74
print(a + b)
# Out:
# 130

# %%
a = 56
b = 74
c = a + b
print(c)
print(type(c))
# Out:
# 130
# <class 'int'>

# %%
a = 56
b = 74.8
c = a + b
print(c)
print(type(c))
# Out:
# 130.8
# <class 'float'>

# %%
aa = 689
print(aa)
print(type(aa))
bb = float(aa)
print(bb)
print(type(bb))
# Out:
# 689
# <class 'int'>
# 689.0
# <class 'float'>

# %%
aa = 689
print(aa)
print(type(aa))
bb = str(aa)
print(bb)
print(type(bb))
# Out:
# 689
# <class 'int'>
# 689
# <class 'str'>

# %%
cc = "python"
print(cc)
dd = int(cc)
print(dd)
# Out:
# python
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 cc = "python"
#       2 print(cc)
# ----> 3 dd = int(cc)
#       4 print(dd)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
# input function

x = input("Enter your value")
print(x)
print(type(x))
# Out:
# 785
# <class 'str'>

# %%
x = int(input("Enter your value"))
print(x)
print(type(x))
# Out:
# 8567
# <class 'int'>

# %%
x = float(input("Enter your value"))
print(x)
print(type(x))
# Out:
# 6.0
# <class 'float'>

# %%
x = complex(input("Enter your value"))
print(x)
print(type(x))
# Out:
# (756+0j)
# <class 'complex'>

# %%
x = complex(input("Enter your value"))
print(x)
print(type(x))
y = int(x)
print(type(y))
print(y)
# Out:
# (56+0j)
# <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       2 print(x)
#       3 print(type(x))
# ----> 4 y = int(x)
#       5 print(type(y))
#       6 print(y)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
x = input("Enter your value")
print(x)
print(type(x))
y = int(x)
print(type(y))
print(y)
# Out:
# mouse
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       2 print(x)
#       3 print(type(x))
# ----> 4 y = int(x)
#       5 print(type(y))
#       6 print(y)
#
# ValueError: invalid literal for int() with base 10: 'mouse'

# %%
x = input("Enter your value")
print(x)
print(type(x))
print(len(x))
# Out:
# loop
# <class 'str'>
# 4

# %%
x = int(input("Enter your value"))
print(x)
print(type(x))
print(len(x))
# Out:
# 58495
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 print(x)
#       3 print(type(x))
# ----> 4 print(len(x))
#
# TypeError: object of type 'int' has no len()

# %%
u = 8938
print(len(u))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 u = 8938
# ----> 2 print(len(u))
#
# TypeError: object of type 'int' has no len()
