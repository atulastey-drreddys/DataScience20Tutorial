# %% [markdown]
# # Conditional Statement

# %%
a = 45
b = 90
print(a > b)
# Out:
# False

# %%
a = 45
if a > 0:
    print("Positive",a)
# Out:
# Positive 45

# %%
a = -45
if a > 0:
    print("Positive",a)

# %%
a = -45
if a > 0:
    print("Positive",a)
else:
    print("Negative",a)
    print("Code Complete")
# Out:
# Negative -45
# Code Complete

# %%
a = 45
if a > 0:
    print("Positive",a)
else:
    print("Negative",a)
print("Code Complete")
# Out:
# Positive 45
# Code Complete

# %%
a = int(input("Enter your value of a:"))
if a > 0:
    print("Positive",a)
else:
    print("Negative",a)
print("Code Complete")
# Out:
# Negative -6576
# Code Complete

# %%
a = int(input("Enter your value of a:"))
if a > 0:
    print("Positive",a)
elif a < 0:
    print("Negative",a)
else:
    print("Zero",a)
print("Code Complete")
# Out:
# Zero 0
# Code Complete

# %%
x = int(input("Enter your first value" ))
y = int(input("Enter your second value" ))
if x > y:
    print("X is great",x)
else:
    print("Y is great",y)
# Out:
# X is great 839

# %%
x = int(input("Enter your first value" ))
y = int(input("Enter your second value" ))
z = int(input("Enter your Third value" ))
print(x,y,z)
if x > y and x > z:
    print("X is great",x)
elif y > x and y > z:
    print("Y is great",y)
else:
    print("Z is great",z)
# Out:
# 100 536 74
# Y is great 536

# %%
u = 'python'
if 'u' in u:
    print("Member")
else:
    print("Not Member")
# Out:
# Not Member

# %%
x = int(input("Enter your first value" ))
if x%2 == 0:
    print("Even Number",x)
else:
    print("Odd",x)
# Out:
# Odd 89

# %%
x = int(input("Enter your first value" ))
if x%3 == 0:
    print("Number is divisible by 3",x)
else:
    print("Number is not divisible by 3",x)
# Out:
# Number is divisible by 3 90

# %%
x = int(input("Enter your first value" ))
if x%5 == 0 and x%7 == 0:
    print("Number is divisible by 5 and 7",x)
else:
    print("Number is not divisible by 5 and 7",x)
# Out:
# Number is divisible by 5 and 7 35

# %%
# Code made by Hariom
unit=int(input("enter units"))
#A=100*5
if unit<100:
    print("no charge")
elif unit<=200:
    unit=unit-100
    print("the electricity bill is-:",unit*5)
elif unit>200:
    unit=unit-200
    unit=(unit*10)+500
    print("the electricity bill is-:",unit)
# Out:
# no charge

# %%
x = 45
y = 90
z = 30
avg = x + y + z/3
print(avg)
# Out:
# 145.0

# %%
x = 45
y = 90
z = 30
avg = (x + y + z)/3
print(avg)
# Out:
# 55.0

# %%
num = int(input("Enter your value"))
if num != 0:
    if num > 0:
        print("Positive",num)
    else:
        print("Negative",num)
else:
    print("Zero",num)
# Out:
# Negative -546

# %%
age = int(input("Enter your age"))
country = input('Enter your country name')
if country == 'india':
    if age >= 18 and age <= 100:
        print("You are eligible for voting")
    else:
        print("Your age is not enough for voting")
else:
    print("Indian citizen is eligible for voting")
# Out:
# Indian citizen is eligible for voting
