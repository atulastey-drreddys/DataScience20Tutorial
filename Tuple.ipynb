# %%
tup = ()
print(tup)
print(type(tup))
print(len(tup))
# Out:
# ()
# <class 'tuple'>
# 0

# %%
tup1 = (453,654,75,"Hello",'watch',True,0, False, None)
print(tup1)
print(type(tup1))
# Out:
# (453, 654, 75, 'Hello', 'watch', True, 0, False, None)
# <class 'tuple'>

# %%
print(tup1)
print(tup1[2])
print(tup1[7])
print(tup1[-2])
print(tup1[2:7])
print(tup1[-8:-2])
print(tup1[-2:-8:-1])
print(tup1[::-1])
# Out:
# (453, 654, 75, 'Hello', 'watch', True, 0, False, None)
# 75
# False
# False
# (75, 'Hello', 'watch', True, 0)
# (654, 75, 'Hello', 'watch', True, 0)
# (False, 0, True, 'watch', 'Hello', 75)
# (None, False, 0, True, 'watch', 'Hello', 75, 654, 453)

# %%
tp = ('python','ruby','java','perl')
out = ('nohtyp','ybur','avaj','lrep')
print(tp)
tp_list = list(tp)
print(tp_list)
print(type(tp_list))
new_list = []
for i in tp_list:
    print("ORiginal input")
    print(i)
    var = i[::-1]
    print("reverserd Output")
    print(var)
    new_list.append(var)
print(tuple(new_list))
# Out:
# ('python', 'ruby', 'java', 'perl')
# ['python', 'ruby', 'java', 'perl']
# <class 'list'>
# ORiginal input
# python
# reverserd Output
# nohtyp
# ORiginal input
# ruby
# reverserd Output
# ybur
# ORiginal input
# java
# reverserd Output
# avaj
# ORiginal input
# perl
# reverserd Output
# lrep
# ('nohtyp', 'ybur', 'avaj', 'lrep')

# %%
# Explicit tuple packing
tp = ('python','ruby',63745,'java',346,'perl')
print(tp)
print(type(tup))
# Out:
# ('python', 'ruby', 63745, 'java', 346, 'perl')
# <class 'tuple'>

# %%
# Implite 
tpp = "python",'ruby','java'
print(tpp)
print(type(tpp))
# Out:
# ('python', 'ruby', 'java')
# <class 'tuple'>

# %%
x,y,z  = 'python','r','perl'
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# python
# <class 'str'>
# r
# <class 'str'>
# perl
# <class 'str'>

# %%
x,y,z  = 'python','r','perl','java','react','laravel'
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x,y,z  = 'python','r','perl','java','react','laravel'
#       2 print(x)
#       3 print(type(x))
#
# ValueError: too many values to unpack (expected 3)

# %%
x,y,*z  = 'python','r','perl','java','react','laravel'
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# python
# <class 'str'>
# r
# <class 'str'>
# ['perl', 'java', 'react', 'laravel']
# <class 'list'>

# %%
x,*y,z  = 'python','r','perl','java','react','laravel'
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# python
# <class 'str'>
# ['r', 'perl', 'java', 'react']
# <class 'list'>
# laravel
# <class 'str'>

# %%
x,y,*z  = ('python','r','perl','java','react','laravel')
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# python
# <class 'str'>
# r
# <class 'str'>
# ['perl', 'java', 'react', 'laravel']
# <class 'list'>

# %%
x = 5849
vv = x % 10 # to extract unit digit
print(vv) 
count = 0
x//10
print(x)
count += 1
# Out:
# 9
# 5849

# %%
9//10
# Out:
# 0
