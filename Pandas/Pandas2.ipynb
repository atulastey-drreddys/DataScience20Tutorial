# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('penguins.csv')
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   0  Adelie  Torgersen            39.1           18.7              181.0
# 1   1  Adelie  Torgersen            39.5           17.4              186.0
# 2   2  Adelie  Torgersen            40.3           18.0              195.0
# 3   3  Adelie  Torgersen             NaN            NaN                NaN
# 4   4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#         id  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
df.isnull().all()
# Out:
# id                   False
# species              False
# island               False
# bill_length_mm       False
# bill_depth_mm        False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# year                 False
# dtype: bool

# %%
df.isnull().any()
# Out:
# id                   False
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df['species'].nunique()
# Out:
# 3

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df['species'].value_counts().index
# Out:
# Index(['Adelie', 'Gentoo', 'Chinstrap'], dtype='object', name='species')

# %%
df['species'].value_counts().values
# Out:
# array([152, 124,  68], dtype=int64)

# %%
df.shape
# Out:
# (344, 9)

# %%
df.dropna()
# Out:
#       id    species     island  bill_length_mm  bill_depth_mm  \
# 0      0     Adelie  Torgersen            39.1           18.7
# 1      1     Adelie  Torgersen            39.5           17.4
# 2      2     Adelie  Torgersen            40.3           18.0
# 4      4     Adelie  Torgersen            36.7           19.3
# 5      5     Adelie  Torgersen            39.3           20.6
# ..   ...        ...        ...             ...            ...
# 339  339  Chinstrap      Dream            55.8           19.8
# 340  340  Chinstrap      Dream            43.5           18.1
# 341  341  Chinstrap      Dream            49.6           18.2
# 342  342  Chinstrap      Dream            50.8           19.0
# 343  343  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %%
df.dropna(axis = 1)
# Out:
#       id    species     island  year
# 0      0     Adelie  Torgersen  2007
# 1      1     Adelie  Torgersen  2007
# 2      2     Adelie  Torgersen  2007
# 3      3     Adelie  Torgersen  2007
# 4      4     Adelie  Torgersen  2007
# ..   ...        ...        ...   ...
# 339  339  Chinstrap      Dream  2009
# 340  340  Chinstrap      Dream  2009
# 341  341  Chinstrap      Dream  2009
# 342  342  Chinstrap      Dream  2009
# 343  343  Chinstrap      Dream  2009
#
# [344 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       id    species     island  bill_length_mm  bill_depth_mm  \
# 0      0     Adelie  Torgersen            39.1           18.7
# 1      1     Adelie  Torgersen            39.5           17.4
# 2      2     Adelie  Torgersen            40.3           18.0
# 3      3     Adelie  Torgersen             NaN            NaN
# 4      4     Adelie  Torgersen            36.7           19.3
# ..   ...        ...        ...             ...            ...
# 339  339  Chinstrap      Dream            55.8           19.8
# 340  340  Chinstrap      Dream            43.5           18.1
# 341  341  Chinstrap      Dream            49.6           18.2
# 342  342  Chinstrap      Dream            50.8           19.0
# 343  343  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %%
df.drop('id',axis = 1)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
df.columns
# Out:
# Index(['id', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
df.rename(columns={'flipper_length_mm':'flip_len_mm'},)
# Out:
#       id    species     island  bill_length_mm  bill_depth_mm  flip_len_mm  \
# 0      0     Adelie  Torgersen            39.1           18.7        181.0
# 1      1     Adelie  Torgersen            39.5           17.4        186.0
# 2      2     Adelie  Torgersen            40.3           18.0        195.0
# 3      3     Adelie  Torgersen             NaN            NaN          NaN
# 4      4     Adelie  Torgersen            36.7           19.3        193.0
# ..   ...        ...        ...             ...            ...          ...
# 339  339  Chinstrap      Dream            55.8           19.8        207.0
# 340  340  Chinstrap      Dream            43.5           18.1        202.0
# 341  341  Chinstrap      Dream            49.6           18.2        193.0
# 342  342  Chinstrap      Dream            50.8           19.0        210.0
# 343  343  Chinstrap      Dream            50.2           18.7        198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
df.columns
# Out:
# Index(['id', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
df.rename(columns={'flipper_length_mm':'flip_len_mm',
                   "body_mass_g":"Body_m_g"},
                   inplace=True)

# %%
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flip_len_mm  \
# 0   0  Adelie  Torgersen            39.1           18.7        181.0
# 1   1  Adelie  Torgersen            39.5           17.4        186.0
# 2   2  Adelie  Torgersen            40.3           18.0        195.0
# 3   3  Adelie  Torgersen             NaN            NaN          NaN
# 4   4  Adelie  Torgersen            36.7           19.3        193.0
#
#    Body_m_g     sex  year
# 0    3750.0    male  2007
# 1    3800.0  female  2007
# 2    3250.0  female  2007
# 3       NaN     NaN  2007
# 4    3450.0  female  2007

# %%
df.isnull().sum()
# Out:
# id                 0
# species            0
# island             0
# bill_length_mm     0
# bill_depth_mm      2
# flip_len_mm        2
# Body_m_g           2
# sex               11
# year               0
# dtype: int64

# %%
df.describe()
# Out:
#                id  bill_length_mm  bill_depth_mm  flip_len_mm     Body_m_g  \
# count  344.000000      342.000000     342.000000   342.000000   342.000000
# mean   171.500000       43.921930      17.151170   200.915205  4201.754386
# std     99.448479        5.459584       1.974793    14.061714   801.954536
# min      0.000000       32.100000      13.100000   172.000000  2700.000000
# 25%     85.750000       39.225000      15.600000   190.000000  3550.000000
# 50%    171.500000       44.450000      17.300000   197.000000  4050.000000
# 75%    257.250000       48.500000      18.700000   213.000000  4750.000000
# max    343.000000       59.600000      21.500000   231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
df['bill_length_mm'].fillna(43.921930,)
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    55.80000
# 340    43.50000
# 341    49.60000
# 342    50.80000
# 343    50.20000
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
df['bill_length_mm'].fillna(df['bill_length_mm'].mean())

# %%
df['bill_length_mm'].fillna(df['bill_length_mm'].median(),
                            inplace=True)
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\2546776777.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bill_length_mm'].fillna(df['bill_length_mm'].median(),

# %%
df['bill_depth_mm'].fillna(df['bill_depth_mm'].median(),
                           inplace = True)
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\4066304442.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bill_depth_mm'].fillna(df['bill_depth_mm'].median(),

# %%
df['flip_len_mm'].fillna(df['flip_len_mm'].median(),
                         inplace = True)

df['Body_m_g'].fillna(df['Body_m_g'].median(),
                         inplace = True)
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\731527971.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['flip_len_mm'].fillna(df['flip_len_mm'].median(),
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\731527971.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# male      168
# female    165
# Name: count, dtype: int64

# %%
df['sex'].mode()[0]
# Out:
# 'male'

# %%
df['sex'].fillna(df['sex'].mode()[0])
# Out:
# 0        male
# 1      female
# 2      female
# 3        male
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
df['sex'].fillna(method = 'ffill')
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\3344001034.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['sex'].fillna(method = 'ffill')
# 0        male
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
df['sex'].fillna(method = 'bfill')
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_8632\2364824996.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['sex'].fillna(method = 'bfill')
# 0        male
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
hypo = pd.read_excel('hypothyroid.xlsx')
hypo
# Out:
#      age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...
