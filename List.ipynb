# %%
print("Hello List")

# %%
x = [23,54,74,True,"Ruby",False,'Python',0,1,None,23]
print(x)
print(len(x))

# %%
print(x[0])
print(x[5])
print(x[8])
print(x[-2])
print(x[-5])
print(x[-11])
print(x[-12])

# %%
x = [23,54,74,True,"Ruby",False,'Python',0,1,None,23]
print(x)
print(x[2])
print(x[7])
print(x[2:7])
print(x[4:1:2])
print(x[4:1:-1])

# %%
x = [23,54,74,True,["Ruby",False,'Python'],0,1,None,23]
print(x)
print(x[3])
print(x[-3])
print(x[4])
#print(x[4,0])
print(x[4][-2])
print(x[4][-3])
#print(x[4][-4])
print(x[4][1:])
print(x[4][:2])
print(x[4][1:2])

# %%
x = [23,54,74,True,["Ruby",False,'Python'],[0,1,None,[23]]]
print(x)
new_list = []
for i in x:
    if isinstance(i,list):
        new_list.extend(i)
    else:
        new_list.append(i)
print(new_list)

# %%
u = ['naman','vinay']
u.append('David')
print(u)

# %%
u.append('Backham')

# %%
u.append(['Backham'])

# %%
u

# %%
u.extend("Rajni")
u

# %%
u.extend(["Rajni"])
u

# %%
i = ['Ayushi','ayush']
j = ['Rohit','rizwan']
k = i + j
print(k)

# %%
i.append(j)
i

# %%
i = ['Ayushi','ayush']
j = ['Rohit','rizwan']
i.extend(j)
i

# %%
input = [23,54,74,True,["Ruby",False,'Python'],0,1,None,23]
output = [23,54,74,True,"Ruby",False,'Python',0,1,None,23]

# %%
x = int(input())
y = int(input())
print(x,y)
if x > y:
    print('x is great',x)
else:
    print("y is great",y)

# %%
v = ['bottle','mice','pen']
print(v)

# %%
v[2] = 'Duster'
v

# %%
v[:2] = ['book','writingpad']
v

# %%
# insert 
v

# %%
v.insert(2,"Eraser")
v

# %%
v.insert(0,"Sharpner")
v

# %%
v.index("book")

# %%
b = ['Sharpner', 'book', 'writingpad', 'Eraser','writingpad', 'Duster','book']
print(b.index('book',2))
print(b.index('writingpad',3 ))

# %%
list1 = ['Sharpner', 'book', 'writingpad', 'Eraser','writingpad', 'Duster','book']
new_list = []
count = 0
for i in list1:
    if i.lower() == 'book':
        new_list.append(count)
    count += 1
print(new_list)

# %%
list1 = ['Sharpner', 'book', 'writingpad', 'Eraser','writingpad', 'Duster','book']
list1.pop()
print(list1)

# %%
list1.pop()
print(list1)

# %%
list1.pop(2)
print(list1)

# %%
list1.remove('book')
print(list1)

# %%
list1.clear()
print(list1)

# %%
list1.append("printer")
print(list1)

# %%
del list1

# %%
list1

# %%
list2 = ['watch', 'mouse','pen','bottle']
print(list2)
list2.sort()
print(list2)

# %%
list3 = [345,235,543,64,45,765]
list3.sort()
print(list3)

# %%
list3 = [345,235,543,64,45,765]
list3.sort(reverse=True)
print(list3)

# %%
list3.reverse()
print(list3)

# %%
list3 = [345,235,543,64,45,765]
copy_lst = list3.copy() # return shallow copy of the list
print(list3)
print(copy_lst)

# %%
copy_lst[0] = 500
print(copy_lst)
print(list3)

# %%
import numpy as np
arr = np.array([500, 235, 543, 64, 45, 765])
v_arr = arr.view()
print("orignal",arr)
print("View",v_arr)
# Out:
# orignal [500 235 543  64  45 765]
# View [500 235 543  64  45 765]

# %%
arr[0] = 900
print(arr)
print(v_arr)
# Out:
# [900 235 543  64  45 765]
# [900 235 543  64  45 765]

# %%
v_arr[3] = 5783
print(v_arr)
print(arr)
# Out:
# [ 900  235  543 5783   45  765]
# [ 900  235  543 5783   45  765]

# %%
help(list.copy)

# %%
list3.append("Laptop")
print(list3)
print(copy_lst)

# %%
copy_lst.append('CPU')
print(list3)
print(copy_lst)

# %%
# Count
x = [900,  235,  543, 45, 5783,  45, 765]
x.count(543)
# Out:
# 1
