# %%
x = 'python'
print(x)
print(x[10])
# Out:
# python
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 x = 'python'
#       2 print(x)
# ----> 3 print(x[10])
#
# IndexError: string index out of range

# %%
x = 'python"
print(x)
# Out:
#   Cell In[2], line 1
#     x = 'python"
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x = 10
print(x/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 x = 10
# ----> 2 print(x/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    x = int(input())
    y = int(input())
    div = x / y
    print(div)
except ZeroDivisionError:
    print("Can't devide by zero")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 try:
#       2     x = int(input())
# ----> 3     y = int(input())
#       4     div = x / y
#       5     print(div)
#
# ValueError: invalid literal for int() with base 10: 'uyy'

# %%
try:
    x = int(input())
    y = int(input())
    div = x / y
    print(div)
except ZeroDivisionError:
    print("Can't devide by zero")
except ValueError:
    print("Please pass valid input")
# Out:
# Please pass valid input

# %%
try:
    x = int(input())
    y = int(input())
    div = x / y
    print(div)
except ZeroDivisionError:
    print("Can't devide by zero")
except ValueError:
    print("Please pass valid input")
finally:
    print("This is always executable")
# Out:
# Please pass valid input
# This is always executable

# %%
try:
    x = 'python'
    print(x[1])
except IndexError:
    print("Out of index, please pass valid index")
finally:
    print("This is always executable")
# Out:
# y
# This is always executable

# %%
x = 8
y = 90
avg = x + y/2
avg
# Out:
# 53.0

# %%
x = 8
y = 90
avg = (x + y)/2
avg
# Out:
# 49.0

# %%
try:
    x = int(input())
    y = int(input())
    div = x / y
    print(div)
except ZeroDivisionError:
    print("Can't devide by zero")
except ValueError:
    print("Please pass valid input")
else:
    print("Addition", x + y)
    print("Substract",x-y)
# Out:
# 6.0
# Addition 91
# Substract 65

# %%
try:
    x = int(input())
    y = int(input())
    div = x / y
    print(div)
except Exception as arg:
    print(f"Type of Error {arg}")
finally:
    print("Code successfully executed")
# Out:
# 0.5858585858585859
# Code successfully executed
