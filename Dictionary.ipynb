# %%
d1 = {}
print(d1)
print(type(d1))
print(len(d1))
# Out:
# {}
# <class 'dict'>
# 0

# %%
d1 = {"Name":"Atul"}
print(d1)
print(type(d1))
print(len(d1))
# Out:
# {'Name': 'Atul'}
# <class 'dict'>
# 1

# %%
s1 = {546,356,"Atul"}
print(s1)
print(type(s1))
print(len(s1))
# Out:
# {546, 'Atul', 356}
# <class 'set'>
# 3

# %%
s2 = {"Name":"Atul",
      "Age":27,
      "City":"Indore"}
print(s2)
# Out:
# {'Name': 'Atul', 'Age': 27, 'City': 'Indore'}

# %%
s2 = {"first_Name":"Atul",
      "Age":27,
      "City":"Indore",
      "Last_Name":"Singh"}
print(s2)
# Out:
# {'first_Name': 'Atul', 'Age': 27, 'City': 'Indore', 'Last_Name': 'Singh'}

# %%
emp_set = set([587,365,'asd',587])
print(emp_set)
print(type(emp_set))
# Out:
# {'asd', 587, 365}
# <class 'set'>

# %%
d3 = {"Name":['Adity','Jayshre',"Khushi","Jayshre"],
      "Age":[34,56,23,87],
      "Country":['Germany',"USA","Canada",'Jamaica']}
print(d3)
# Out:
# {'Name': ['Adity', 'Jayshre', 'Khushi', 'Jayshre'], 'Age': [34, 56, 23, 87], 'Country': ['Germany', 'USA', 'Canada', 'Jamaica']}

# %%
d5 = {"GrandFather":{"Name":"RaghunathSing","Age":90},
      "Father":{"Name":"DurgaPrasad","Age":57},
      "Self":{"Name":"Vinay","Age":27}}
d5
# Out:
# {'GrandFather': {'Name': 'RaghunathSing', 'Age': 90},
#  'Father': {'Name': 'DurgaPrasad', 'Age': 57},
#  'Self': {'Name': 'Vinay', 'Age': 27}}

# %%
d3 = {"Name":['Adity','Jayshre',"Khushi","Jayshre"],
      "Age":[34,56,23,87],
      "Country":['Germany',"USA","Canada",'Jamaica']}
print(d3)
# Out:
# {'Name': ['Adity', 'Jayshre', 'Khushi', 'Jayshre'], 'Age': [34, 56, 23, 87], 'Country': ['Germany', 'USA', 'Canada', 'Jamaica']}

# %%
d3['Name']
# Out:
# ['Adity', 'Jayshre', 'Khushi', 'Jayshre']

# %%
print(d3['Name'][1])
print(d3['Name'][1:])
# Out:
# Jayshre
# ['Jayshre', 'Khushi', 'Jayshre']

# %%
d3['Name'][1] = 'Rizwan'
d3
# Out:
# {'Name': ['Adity', 'Rizwan', 'Khushi', 'Jayshre'],
#  'Age': [34, 56, 23, 87],
#  'Country': ['Germany', 'USA', 'Canada', 'Jamaica']}

# %%
d3['Qualification'] = ['B.Tech','B.Sc','M.Sc.','B.A']
d3
# Out:
# {'Name': ['Adity', 'Rizwan', 'Khushi', 'Jayshre'],
#  'Age': [34, 56, 23, 87],
#  'Country': 'City',
#  'Qualification': ['B.Tech', 'B.Sc', 'M.Sc.', 'B.A']}

# %%
d3 = {"Name":['Adity','Jayshre',"Khushi","Jayshre"],
      "Age":[34,56,23,87],
      "Country":['Germany',"USA","Canada",'Jamaica']}
print(d3)
for i in d3:
    print(i)
# Out:
# {'Name': ['Adity', 'Jayshre', 'Khushi', 'Jayshre'], 'Age': [34, 56, 23, 87], 'Country': ['Germany', 'USA', 'Canada', 'Jamaica']}
# Name
# Age
# Country

# %%
for i,j in d3.items():
    print(i,j)
# Out:
# Name ['Adity', 'Jayshre', 'Khushi', 'Jayshre']
# Age [34, 56, 23, 87]
# Country ['Germany', 'USA', 'Canada', 'Jamaica']

# %%
import pandas as pd
df = pd.DataFrame(d3)
df
# Out:
#       Name  Age  Country
# 0    Adity   34  Germany
# 1  Jayshre   56      USA
# 2   Khushi   23   Canada
# 3  Jayshre   87  Jamaica
