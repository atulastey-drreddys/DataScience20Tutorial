# %%
se1 = {3,5,7,6,45,7,8,76}
for i in se1:
    print(i)
    if
# Out:
# 3
# 5
# 6
# 7
# 8
# 76
# 45

# %%
s1 = set({})
print(s1)
print(type(s1))
# Out:
# set()
# <class 'set'>

# %%
s2 = {45,674,"python",'ruby',435.6,34.64}
print(s2)
# Out:
# {674, 34.64, 435.6, 'python', 'ruby', 45}

# %%
s2 = {45,0,674,False,"python",True,'ruby',435.6,34.64,1}
print(s2)
# Out:
# {0, True, 674, 34.64, 'ruby', 45, 435.6, 'python'}

# %%
help(set.)
